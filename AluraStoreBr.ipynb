# %% [markdown]
# <a href="https://colab.research.google.com/github/AzKatrine/challenge_one_data_science/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
faturamento_loja = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

print(f'Faturamento total da loja 1: R${faturamento_loja:.2f}')
print(f'Faturamento total da loja 2: R${faturamento_loja2:.2f}')
print(f'Faturamento total da loja 3: R${faturamento_loja3:.2f}')
print(f'Faturamento total da loja 4: R${faturamento_loja4:.2f}')
# Out:
# Faturamento total da loja 1: R$1534509.12
# Faturamento total da loja 2: R$1488459.06
# Faturamento total da loja 3: R$1464025.03
# Faturamento total da loja 4: R$1384497.58

# %%
import matplotlib.pyplot as plt

# Dados para o gráfico
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [faturamento_loja, faturamento_loja2, faturamento_loja3, faturamento_loja4]

# Criando o gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(lojas, faturamentos, color='teal')
plt.title('Faturamento Total por Loja')
plt.ylabel('Faturamento (R$)')
plt.xlabel('Lojas')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Contando os produtos vendidos por categoria
categoria_loja = loja['Categoria do Produto'].value_counts()
categoria_loja2 = loja2['Categoria do Produto'].value_counts()
categoria_loja3 = loja3['Categoria do Produto'].value_counts()
categoria_loja4 = loja4['Categoria do Produto'].value_counts()

# Exibindo os resultados
print("Loja 1:\n", categoria_loja, "\n")
print("Loja 2:\n", categoria_loja2, "\n")
print("Loja 3:\n", categoria_loja3, "\n")
print("Loja 4:\n", categoria_loja4)
# Out:
# Loja 1:
#  Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Loja 2:
#  Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Loja 3:
#  Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64
#
# Loja 4:
#  Categoria do Produto
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criando o DataFrame com os dados manuais
dados = {
    'Categoria do Produto': [
        'moveis', 'eletronicos', 'brinquedos', 'eletrodomesticos',
        'esporte e lazer', 'instrumentos musicais', 'livros', 'utilidades domesticas'
    ],
    'Loja 1': [465, 448, 324, 312, 284, 182, 173, 171],
    'Loja 2': [442, 422, 313, 305, 275, 224, 197, 181],
    'Loja 3': [499, 451, 315, 278, 277, 177, 185, 177],
    'Loja 4': [480, 451, 338, 254, 277, 170, 187, 201],
}

df = pd.DataFrame(dados).set_index('Categoria do Produto')

# Plotando gráfico de barras agrupadas
plt.figure(figsize=(12, 6))
df.plot(kind='bar', width=0.8)
plt.title('Comparativo de Produtos Vendidos por Categoria nas Quatro Lojas')
plt.xlabel('Categoria do Produto')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend(title='Lojas')
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# Calculando a média da avaliação dos clientes por loja
media_avaliacao_loja = loja['Avaliação da compra'].mean()
media_avaliacao_loja2 = loja2['Avaliação da compra'].mean()
media_avaliacao_loja3 = loja3['Avaliação da compra'].mean()
media_avaliacao_loja4 = loja4['Avaliação da compra'].mean()

# Exibindo os resultados
print(f"Média de avaliação - Loja 1: {media_avaliacao_loja:.2f}")
print(f"Média de avaliação - Loja 2: {media_avaliacao_loja2:.2f}")
print(f"Média de avaliação - Loja 3: {media_avaliacao_loja3:.2f}")
print(f"Média de avaliação - Loja 4: {media_avaliacao_loja4:.2f}")
# Out:
# Média de avaliação - Loja 1: 3.98
# Média de avaliação - Loja 2: 4.04
# Média de avaliação - Loja 3: 4.05
# Média de avaliação - Loja 4: 4.00

# %%
import matplotlib.pyplot as plt

# Dados para o gráfico
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
avaliacoes = [
    media_avaliacao_loja,
    media_avaliacao_loja2,
    media_avaliacao_loja3,
    media_avaliacao_loja4
]

# Gráfico
plt.figure(figsize=(8, 5))
plt.bar(lojas, avaliacoes, color='mediumseagreen')
plt.ylim(0, 5)
plt.title('Média das Avaliações dos Clientes por Loja')
plt.ylabel('Média da Avaliação (0 a 5)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Contando a frequência de cada avaliação por loja
dist_loja = loja['Avaliação da compra'].value_counts().sort_index()
dist_loja2 = loja2['Avaliação da compra'].value_counts().sort_index()
dist_loja3 = loja3['Avaliação da compra'].value_counts().sort_index()
dist_loja4 = loja4['Avaliação da compra'].value_counts().sort_index()

# Exibindo as distribuições
print("Distribuição Loja 1:\n", dist_loja, "\n")
print("Distribuição Loja 2:\n", dist_loja2, "\n")
print("Distribuição Loja 3:\n", dist_loja3, "\n")
print("Distribuição Loja 4:\n", dist_loja4)
# Out:
# Distribuição Loja 1:
#  Avaliação da compra
# 1     319
# 2      86
# 3     218
# 4     444
# 5    1292
# Name: count, dtype: int64
#
# Distribuição Loja 2:
#  Avaliação da compra
# 1     273
# 2      93
# 3     209
# 4     482
# 5    1302
# Name: count, dtype: int64
#
# Distribuição Loja 3:
#  Avaliação da compra
# 1     297
# 2      79
# 3     193
# 4     434
# 5    1356
# Name: count, dtype: int64
#
# Distribuição Loja 4:
#  Avaliação da compra
# 1     310
# 2      85
# 3     210
# 4     453
# 5    1300
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Unindo as distribuições em um único DataFrame
df_dist = pd.DataFrame({
    'Loja 1': dist_loja,
    'Loja 2': dist_loja2,
    'Loja 3': dist_loja3,
    'Loja 4': dist_loja4
}).fillna(0).astype(int)

# Plotando gráfico de linhas
plt.figure(figsize=(10, 6))
df_dist.plot(marker='o')
plt.title('Distribuição das Avaliações dos Clientes por Loja')
plt.xlabel('Nota de Avaliação')
plt.ylabel('Quantidade de Avaliações')
plt.xticks(range(1, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend(title='Lojas')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Top 5 mais vendidos
top5_loja = loja['Produto'].value_counts().head(5)
top5_loja2 = loja2['Produto'].value_counts().head(5)
top5_loja3 = loja3['Produto'].value_counts().head(5)
top5_loja4 = loja4['Produto'].value_counts().head(5)

# 5 menos vendidos
bottom5_loja = loja['Produto'].value_counts().tail(5)
bottom5_loja2 = loja2['Produto'].value_counts().tail(5)
bottom5_loja3 = loja3['Produto'].value_counts().tail(5)
bottom5_loja4 = loja4['Produto'].value_counts().tail(5)

# %%
def plot_produtos_top_bottom(top, bottom, loja_nome):
    fig, axs = plt.subplots(1, 2, figsize=(14, 6))

    # Top vendidos
    axs[0].barh(top.index[::-1], top.values[::-1], color='seagreen')
    axs[0].set_title(f'Top 5 Mais Vendidos - {loja}')
    axs[0].set_xlabel('Quantidade Vendida')
    axs[0].invert_yaxis()

    # Menos vendidos
    axs[1].barh(bottom.index, bottom.values, color='indianred')
    axs[1].set_title(f'Top 5 Menos Vendidos - {loja}')
    axs[1].set_xlabel('Quantidade Vendida')

    plt.tight_layout()
    plt.show()

# Exemplo para Loja 1
plot_produtos_top_bottom(top5_loja, bottom5_loja, 'Loja 1')
# Out:
# <ipython-input-11-314e8aae5fe2>:15: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import seaborn as sns

# Criando DataFrames com nome da loja
df_top1 = top5_loja.reset_index()
df_top1.columns = ['Produto', 'Quantidade']
df_top1['Loja'] = 'Loja 1'

df_top2 = top5_loja2.reset_index()
df_top2.columns = ['Produto', 'Quantidade']
df_top2['Loja'] = 'Loja 2'

df_top3 = top5_loja3.reset_index()
df_top3.columns = ['Produto', 'Quantidade']
df_top3['Loja'] = 'Loja 3'

df_top4 = top5_loja4.reset_index()
df_top4.columns = ['Produto', 'Quantidade']
df_top4['Loja'] = 'Loja 4'

# Unindo todos em um único DataFrame
df_top_todas = pd.concat([df_top1, df_top2, df_top3, df_top4], ignore_index=True)

# Ajuste de estilo do gráfico
plt.figure(figsize=(12, 8))
sns.barplot(data=df_top_todas, y='Produto', x='Quantidade', hue='Loja', dodge=True)

plt.title('Top 5 Produtos Mais Vendidos em Cada Loja')
plt.xlabel('Quantidade Vendida')
plt.ylabel('Produto')
plt.legend(title='Loja')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Criando DataFrames com nome da loja
df_bottom1 = bottom5_loja.reset_index()
df_bottom1.columns = ['Produto', 'Quantidade']
df_bottom1['Loja'] = 'Loja 1'

df_bottom2 = bottom5_loja2.reset_index()
df_bottom2.columns = ['Produto', 'Quantidade']
df_bottom2['Loja'] = 'Loja 2'

df_bottom3 = bottom5_loja3.reset_index()
df_bottom3.columns = ['Produto', 'Quantidade']
df_bottom3['Loja'] = 'Loja 3'

df_bottom4 = bottom5_loja4.reset_index()
df_bottom4.columns = ['Produto', 'Quantidade']
df_bottom4['Loja'] = 'Loja 4'

# Unindo todos em um único DataFrame
df_bottom_todas = pd.concat([df_bottom1, df_bottom2, df_bottom3, df_bottom4], ignore_index=True)

# Ajuste de estilo do gráfico
plt.figure(figsize=(12, 8))
sns.barplot(data=df_bottom_todas, y='Produto', x='Quantidade', hue='Loja', dodge=True)

plt.title('Top 5 Produtos Menos Vendidos em Cada Loja')
plt.xlabel('Quantidade Vendida')
plt.ylabel('Produto')
plt.legend(title='Loja')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Concatenar os dados das quatro lojas
todas_lojas = pd.concat([loja, loja2, loja3, loja4], ignore_index=True)

# Contar vendas por produto
ranking_produtos = todas_lojas['Produto'].value_counts()

# Separar Top 10 e Bottom 10
top10_geral = ranking_produtos.head(10)
bottom10_geral = ranking_produtos.tail(10)

# Função para plotar
def plot_ranking(produtos, titulo, cor):
    plt.figure(figsize=(10, 6))
    produtos[::-1].plot(kind='barh', color=cor)
    plt.title(titulo)
    plt.xlabel('Quantidade Vendida')
    plt.ylabel('Produto')
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# Gráfico: Top 10 mais vendidos
plot_ranking(top10_geral, 'Top 10 Produtos Mais Vendidos (Geral)', 'mediumseagreen')

# Gráfico: Top 10 menos vendidos
plot_ranking(bottom10_geral, 'Top 10 Produtos Menos Vendidos (Geral)', 'lightcoral')

# %% [markdown]
# # 5. Frete Médio por Loja
